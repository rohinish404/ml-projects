# %%
import pandas as pd

# %%
df = pd.read_csv('../house-prices/Bengaluru_House_Data.csv')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df['location'].unique().size
# Out:
# 1306

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
f1 = ["balcony","bath","area_type"]
for i,cols in enumerate(f1):
    plt.figure(i)
    sns.countplot(x=df[cols],data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  int64
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       13320 non-null  int64
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 936.7+ KB

# %%
df.isna().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# society           0
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
sns.barplot(x=df['balcony'],y=df['price'])
# Out:
# <AxesSubplot: xlabel='balcony', ylabel='price'>

# %%
df_new = df.drop(['availability','society','price'],axis='columns')
target = df['price']
df_new
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13316  Super built-up  Area             Richards Town      4 BHK       3600
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
# 13319  Super built-up  Area              Doddathoguru      1 BHK        550
#
#        bath  balcony
# 0       2.0      1.0
# 1       5.0      3.0
# 2       2.0      3.0
# 3       3.0      1.0
# 4       2.0      1.0
# ...     ...      ...
# 13315   4.0      0.0
# 13316   5.0      NaN
# 13317   2.0      1.0
# 13318   4.0      1.0
# 13319   1.0      1.0
#
# [13320 rows x 6 columns]

# %%
df_new.isna().sum()
# Out:
# area_type       0
# location        1
# size           16
# total_sqft      0
# bath           73
# balcony       609
# dtype: int64

# %%
df.groupby(['size']).count()
# Out:
#             area_type  availability  location  society  total_sqft  bath  \
# size
# 1 BHK             538           538       538      538         538   531
# 1 Bedroom         105           105       105      105         105   105
# 1 RK               13            13        13       13          13    13
# 10 BHK              2             2         2        2           2     2
# 10 Bedroom         12            12        12       12          12    12
# 11 BHK              2             2         2        2           2     2
# 11 Bedroom          2             2         2        2           2     2
# 12 Bedroom          1             1         1        1           1     1
# 13 BHK              1             1         1        1           1     1
# 14 BHK              1             1         1        1           1     1
# 16 BHK              1             1         1        1           1     1
# 18 Bedroom          1             1         1        1           1     1
# 19 BHK              1             1         1        1           1     1
# 2 BHK            5199          5199      5199     5199        5199  5198
# 2 Bedroom         329           329       329      329         329   329
# 27 BHK              1             1         1        1           1     1
# 3 BHK            4310          4310      4309     4310        4310  4287
# 3 Bedroom         547           547       547      547         547   546
# 4 BHK             591           591       591      591         591   577
# 4 Bedroom         826           826       826      826         826   818
# 43 Bedroom          1             1         1        1           1     1
# 5 BHK              59            59        59       59          59    57
# 5 Bedroom         297           297       297      297         297   296
# 6 BHK              30            30        30       30          30    30
# 6 Bedroom         191           191       191      191         191   191
# 7 BHK              17            17        17       17          17    17
# 7 Bedroom          83            83        83       83          83    83
# 8 BHK               5             5         5        5           5     5
# 8 Bedroom          84            84        84       84          84    84
# 9 BHK               8             8         8        8           8     8
# 9 Bedroom          46            46        46       46          46    46
#
#             balcony  price
# size
# 1 BHK           530    538
# 1 Bedroom       105    105
# 1 RK             13     13
# 10 BHK            0      2
# 10 Bedroom        3     12
# 11 BHK            1      2
# 11 Bedroom        2      2
# 12 Bedroom        1      1
# 13 BHK            1      1
# 14 BHK            1      1
# 16 BHK            0      1
# 18 Bedroom        0      1
# 19 BHK            0      1
# 2 BHK          5152   5199
# 2 Bedroom       328    329
# 27 BHK            1      1
# 3 BHK          4129   4310
# 3 Bedroom       527    547
# 4 BHK           489    591
# 4 Bedroom       749    826
# 43 Bedroom        1      1
# 5 BHK            36     59
# 5 Bedroom       263    297
# 6 BHK            23     30
# 6 Bedroom       169    191
# 7 BHK            16     17
# 7 Bedroom        69     83
# 8 BHK             3      5
# 8 Bedroom        65     84
# 9 BHK             5      8
# 9 Bedroom        29     46

# %%
df_new['size'] = df_new['size'].fillna('2 BHK')

# %%
from sklearn import preprocessing 
label = preprocessing.LabelEncoder()
df['society'] = label.fit_transform(df['society'])
df['availability'] = label.fit_transform(df['availability'])
f1=['availability','society','price']
sns.heatmap(df[f1].corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
f2=['bath','balcony','price']
sns.heatmap(df[f2].corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
df_new['size'] = label.fit_transform(df_new['size'])
f=['size','price']
sns.heatmap(df[f].corr(),annot=True)
# Out:
# <AxesSubplot: >
